# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt


data = pd.read_csv("modified_data.csv", delimiter=',', nrows=300000)

means = data.groupby('SMK_stat_type_cd').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data.columns[i])

# plt.tight_layout()
plt.show()

# %%
data_men = pd.read_csv("male_data.csv", delimiter=',', nrows=300000)

means = data_men.groupby('SMK_stat_type_cd').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data_men.columns[i])

# plt.tight_layout()
plt.show()

# %%
data_females = pd.read_csv("female_data.csv", delimiter=',', nrows=300000)

means = data_females.groupby('SMK_stat_type_cd').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data_females.columns[i])

# plt.tight_layout()
plt.show()

# %%
means = data.groupby('DRK_YN').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data.columns[i])

# plt.tight_layout()
plt.show()

# %%
means = data_men.groupby('DRK_YN').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data_men.columns[i])

# plt.tight_layout()
plt.show()

# %%
means = data_females.groupby('DRK_YN').mean()

# Create a single figure with multiple subplots
num_columns = len(means.columns)
fig, axes = plt.subplots(1, num_columns, figsize=(50, 20))

for i, column in enumerate(means.columns):
    means[column].plot(kind='bar', rot=0, ax=axes[i])
    axes[i].set_xlabel(data_females.columns[i])

# plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('dataset.csv', delimiter=',')
data['sex'] = data['sex'].replace({'Male': 1, 'Female': 0})
data['DRK_YN'] = data['DRK_YN'].replace({'Y': 1, 'N': 0})

correlation_matrix = data.corr().round(2)

plt.figure(figsize=(8, 6))  # Размер графика
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Добавьте название графика
plt.title('Корреляционная матрица')

# Отобразите график
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('male_data.csv', delimiter=',')
data['sex'] = data['sex'].replace({'Male': 1, 'Female': 0})
data['DRK_YN'] = data['DRK_YN'].replace({'Y': 1, 'N': 0})

correlation_matrix = data.corr().round(2)

plt.figure(figsize=(8, 6))  # Размер графика
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Добавьте название графика
plt.title('Корреляционная матрица')

# Отобразите график
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('female_data.csv', delimiter=',')
data['sex'] = data['sex'].replace({'Male': 1, 'Female': 0})
data['DRK_YN'] = data['DRK_YN'].replace({'Y': 1, 'N': 0})

correlation_matrix = data.corr().round(2)

plt.figure(figsize=(8, 6))  # Размер графика
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Добавьте название графика
plt.title('Корреляционная матрица')

# Отобразите график
plt.show()
